# %%
import pandas as pd
import datetime
import matplotlib.pyplot as plt
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly
import plotly.graph_objs as go
import seaborn as sns
#sns.set_style("dark")
#sns.set_palette("RdBu")
#sns.set_context("notebook", font_scale = 1.5, 
#                rc = { "figure.figsize" : (15, 5), "axes.titlesize" : 18 })
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
df = pd.read_csv('howpop_train.csv')

df['published'] = pd.to_datetime(df['published']).dt.date

df['published'] = df['published'].apply(lambda x: datetime.datetime.strftime(x, '%Y-%m'))

tab = df.groupby(['published']).count()

trace = go.Bar(
    x = tab.index,
    y = tab['url']
)
layout = go.Layout(
    title='barchart',
)

fig = go.Figure(data = [trace], layout = layout)
iplot(fig)
# Out:
# <div id="d9072413-78d2-45ab-aea6-10a36e1e93b0" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d9072413-78d2-45ab-aea6-10a36e1e93b0", [{"x": ["2008-01", "2008-02", "2008-03", "2008-04", "2008-05", "2008-06", "2008-07", "2008-08", "2008-09", "2008-10", "2008-11", "2008-12", "2009-01", "2009-02", "2009-03", "2009-04", "2009-05", "2009-06", "2009-07", "2009-08", "2009-09", "2009-10", "2009-11", "2009-12", "2010-01", "2010-02", "2010-03", "2010-04", "2010-05", "2010-06", "2010-07", "2010-08", "2010-09", "2010-10", "2010-11", "2010-12", "2011-01", "2011-02", "2011-03", "2011-04", "2011-05", "2011-06", "2011-07", "2011-08", "2011-09", "2011-10", "2011-11", "2011-12", "2012-01", "2012-02", "2012-03", "2012-04", "2012-05", "2012-06", "2012-07", "2012-08", "2012-09", "2012-10", "2012-11", "2012-12", "2013-0
# ...

# %%
df = pd.read_csv('howpop_train.csv')

df['published'] = pd.to_datetime(df['published']).dt.date
df['published'] = df['published'].apply(lambda x: datetime.datetime.strftime(x, '%Y-%m-%d'))

df = df[(df['published'] >= '2015-03-01') & (df['published'] <= '2015-03-31')]

# %%
g = sns.FacetGrid(df, row="published", col="domain", hue="published")
g.map(plt.scatter, "published", "domain")
g.add_legend()

# %%
df
# Out:
#                                                      url        domain  \
# 97666                  https://habrahabr.ru/post/251783/  habrahabr.ru
# 97667  https://habrahabr.ru/company/kolibrios/blog/23...  habrahabr.ru
# 97668                  https://habrahabr.ru/post/286286/  habrahabr.ru
# 97669                  https://habrahabr.ru/post/251347/  habrahabr.ru
# 97670                  https://habrahabr.ru/post/251765/  habrahabr.ru
# 97671                  https://habrahabr.ru/post/251793/  habrahabr.ru
# 97672                  https://habrahabr.ru/post/251747/  habrahabr.ru
# 97673  https://geektimes.ru/company/soundpal/blog/246...  geektimes.ru
# 97674                  https://geektimes.ru/post/246572/  geektimes.ru
# 97675                  https://habrahabr.ru/post/251797/  habrahabr.ru
# 97676                  https://habrahabr.ru/post/251077/  habrahabr.ru
# 97677                  https://habrahabr.ru/post/251801/  habrahabr.ru
# ...

# %%
df['domain'] == 'habrahabr.ru'
# Out:
# 97666     True
# 97667     True
# 97668     True
# 97669     True
# 97670     True
# 97671     True
# 97672     True
# 97673    False
# 97674    False
# 97675     True
# 97676     True
# 97677     True
# 97678     True
# 97679     True
# 97680    False
# 97681     True
# 97682     True
# 97683     True
# 97684     True
# 97685    False
# 97686    False
# 97687     True
# 97688     True
# 97689     True
# 97690    False
# 97691     True
# 97692     True
# 97693     True
# 97694     True
# 97695     True
#          ...
# 99825     True
# 99826     True
# 99827     True
# 99828     True
# 99829     True
# 99830     True
# 99831    False
# 99832    False
# 99833     True
# 99834    False
# 99835     True
# 99836     True
# 99837    False
# 99838    False
# 99839    False
# 99840    False
# 99841     True
# 99842    False
# 99843    False
# 99844    False
# 99845     True
# 99846     True
# 99847     True
# 99848     True
# 99849     True
# 99850    False
# 99851     True
# ...

# %%
df = df.groupby(['domain', 'published']).count()

# %%
trace0 = go.Scatter(
   # x = df.index,
    y = df.loc['geektimes.ru']['url']
)

trace1 = go.Scatter(
   # x = df.index,
    y = df.loc['habrahabr.ru']['url']
)


# определяем массив данных и задаем title графика в layout
data = [trace0, trace1]
layout = {'title': 'Statistics of geektimes and habr'}

# cоздаем объект Figure и визуализируем его
fig = go.Figure(data=data, layout=layout)
iplot(fig, show_link=False)
# Out:
# <div id="fe024733-e7b4-4617-a919-d7b57bae8a9b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("fe024733-e7b4-4617-a919-d7b57bae8a9b", [{"y": [6, 25, 29, 37, 31, 21, 11, 8, 18, 29, 26, 30, 24, 17, 11, 32, 38, 29, 29, 28, 14, 12, 27, 33, 32, 26, 34, 15, 15, 27, 41], "type": "scatter", "uid": "ee006f3b-31bd-4b3d-830d-4f926d0d88a1"}, {"y": [26, 73, 65, 61, 41, 50, 20, 18, 24, 69, 66, 69, 54, 13, 19, 67, 69, 51, 59, 46, 8, 18, 51, 53, 60, 63, 58, 17, 23, 52, 71], "type": "scatter", "uid": "23fa820b-93de-47e8-b929-b2c32e317776"}], {"title": "Statistics of geektimes and habr"}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById(
# ...

# %%
import datetime
DayL = ['Mon','Tues','Wednes','Thurs','Fri','Satur','Sun']
date = DayL[datetime.date(2015,3,27).weekday()] + 'day'
#Set day, month, year to your value
#Now, date is set as an actual day, not a number from 0 to 6.

print(date)
# Out:
# Friday

# %%
dff = pd.read_csv('howpop_train.csv')

# %%
dff['A'], dff['B'] = dff['published'].str.split(' ', 1).str
dff.head()
# Out:
#                                 url        domain  post_id  \
# 0  https://habrahabr.ru/post/18284/  habrahabr.ru    18284
# 1  https://habrahabr.ru/post/18285/  habrahabr.ru    18285
# 2  https://habrahabr.ru/post/18286/  habrahabr.ru    18286
# 3  https://habrahabr.ru/post/18291/  habrahabr.ru    18291
# 4  https://geektimes.ru/post/18294/  geektimes.ru    18294
#
#              published      author     flow  polling  content_len  \
# 0  2008-01-01 18:19:00      @Tapac  develop    False         4305
# 1  2008-01-01 18:30:00  @DezmASter   design    False         7344
# 2  2008-01-01 18:34:00  @DezmASter   design    False         8431
# 3  2008-01-02 01:32:00    @Taoorus   design    False         5662
# 4  2008-01-02 14:34:00    @dennydo      NaN    False         3706
#
#                                                title  comments  favs  views  \
# 0     Новогодний подарок блоггерам — WordPress 2.3.2         0     0    236
# ...

# %%
dff['comments']
# Out:
# 0           0
# 1           1
# 2          47
# 3         102
# 4         230
# 5          22
# 6          10
# 7          64
# 8          23
# 9           6
# 10         50
# 11        154
# 12        406
# 13         22
# 14        177
# 15        105
# 16         19
# 17         30
# 18          2
# 19         19
# 20         83
# 21         10
# 22          2
# 23         37
# 24         18
# 25          6
# 26         36
# 27         44
# 28          0
# 29         19
#          ...
# 134107     91
# 134108      3
# 134109     43
# 134110     11
# 134111      6
# 134112     75
# 134113     59
# 134114     13
# 134115     39
# 134116      7
# 134117     22
# 134118      1
# 134119     14
# 134120     34
# 134121     16
# 134122      3
# 134123      7
# 134124     12
# 134125      2
# 134126     19
# 134127     16
# 134128     31
# 134129     12
# 134130     30
# 134131     82
# 134132     58
# 134133     52
# 134134     16
# 134135     47
# 134136      4
# ...

# %%
dff.groupby(['B']).count().index
# Out:
# Index(['00:00:00', '00:01:00', '00:02:00', '00:03:00', '00:04:00', '00:05:00',
#        '00:06:00', '00:07:00', '00:08:00', '00:09:00',
#        ...
#        '23:50:00', '23:51:00', '23:52:00', '23:53:00', '23:54:00', '23:55:00',
#        '23:56:00', '23:57:00', '23:58:00', '23:59:00'],
#       dtype='object', name='B', length=1440)

# %%
dff.groupby(['domain', 'B']).sum().loc['geektimes.ru']['comments']
# Out:
# B
# 00:00:00    1872
# 00:01:00    1538
# 00:02:00    2084
# 00:03:00     782
# 00:04:00    1414
# 00:05:00    1442
# 00:06:00    1419
# 00:07:00    1991
# 00:08:00    1080
# 00:09:00    1326
# 00:10:00     824
# 00:11:00    1651
# 00:12:00    1062
# 00:13:00     727
# 00:14:00    1215
# 00:15:00    1821
# 00:16:00    1718
# 00:17:00    1115
# 00:18:00    1066
# 00:19:00     735
# 00:20:00     903
# 00:21:00     627
# 00:22:00    1445
# 00:23:00     928
# 00:24:00     879
# 00:25:00    2060
# 00:26:00     481
# 00:27:00     702
# 00:28:00    1009
# 00:29:00    2219
#             ...
# 23:30:00     872
# 23:31:00    1183
# 23:32:00    2191
# 23:33:00    1428
# 23:34:00    1508
# 23:35:00    1660
# 23:36:00    1066
# 23:37:00    1297
# 23:38:00    2082
# 23:39:00    1383
# 23:40:00    1294
# 23:41:00    2276
# 23:42:00    1202
# 23:43:00    1003
# 23:44:00    2113
# 23:45:00    1335
# 23:46:00    1038
# 23:47:00    2887
# 23:48:00     835
# 23:49:00     893
# 23:50:00    1295
# ...

# %%
trace0 = go.Scatter(
    x = dff.groupby(['domain', 'B']).count().loc['geektimes.ru'].index,
    y = dff.groupby(['domain', 'B']).sum().loc['geektimes.ru']['comments']
)

trace1 = go.Scatter(
    x = dff.groupby(['domain', 'B']).count().loc['habrahabr.ru'].index,
    y = dff.groupby(['domain', 'B']).sum().loc['habrahabr.ru']['comments']
)


# определяем массив данных и задаем title графика в layout
data = [trace0, trace1]
layout = {'title': 'Statistics of geektimes, habrahabr'}

# cоздаем объект Figure и визуализируем его
fig = go.Figure(data=data, layout=layout)
iplot(fig, show_link=False)
# Out:
# <div id="cf2af841-c8e4-49a8-a669-77e3088dab8f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("cf2af841-c8e4-49a8-a669-77e3088dab8f", [{"x": ["00:00:00", "00:01:00", "00:02:00", "00:03:00", "00:04:00", "00:05:00", "00:06:00", "00:07:00", "00:08:00", "00:09:00", "00:10:00", "00:11:00", "00:12:00", "00:13:00", "00:14:00", "00:15:00", "00:16:00", "00:17:00", "00:18:00", "00:19:00", "00:20:00", "00:21:00", "00:22:00", "00:23:00", "00:24:00", "00:25:00", "00:26:00", "00:27:00", "00:28:00", "00:29:00", "00:30:00", "00:31:00", "00:32:00", "00:33:00", "00:34:00", "00:35:00", "00:36:00", "00:37:00", "00:38:00", "00:39:00", "00:40:00", "00:41:00", "00:42:00", "00:43:00", "00:44:00", "00:45:00", "00:46:00", "00:47:00", "00:48:00", "00:49:00", "00:50:00", "00:51:00", "00:52:00", "00:53:00", "00:54:00", "00:55:
# ...

# %%
trace0 = go.Scatter(
    x = dff.groupby(['domain', 'B']).count().loc['geektimes.ru'].index,
    y = dff.groupby(['domain', 'B']).sum().loc['geektimes.ru']['views']
)

trace1 = go.Scatter(
    x = dff.groupby(['domain', 'B']).count().loc['habrahabr.ru'].index,
    y = dff.groupby(['domain', 'B']).sum().loc['habrahabr.ru']['views']
)


# определяем массив данных и задаем title графика в layout
data = [trace0, trace1]
layout = {'title': 'Statistics of geektimes, habrahabr'}

# cоздаем объект Figure и визуализируем его
fig = go.Figure(data=data, layout=layout)
iplot(fig, show_link=False)
# Out:
# <div id="ee8888e1-e906-43a4-95d3-d57d7164795f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ee8888e1-e906-43a4-95d3-d57d7164795f", [{"x": ["00:00:00", "00:01:00", "00:02:00", "00:03:00", "00:04:00", "00:05:00", "00:06:00", "00:07:00", "00:08:00", "00:09:00", "00:10:00", "00:11:00", "00:12:00", "00:13:00", "00:14:00", "00:15:00", "00:16:00", "00:17:00", "00:18:00", "00:19:00", "00:20:00", "00:21:00", "00:22:00", "00:23:00", "00:24:00", "00:25:00", "00:26:00", "00:27:00", "00:28:00", "00:29:00", "00:30:00", "00:31:00", "00:32:00", "00:33:00", "00:34:00", "00:35:00", "00:36:00", "00:37:00", "00:38:00", "00:39:00", "00:40:00", "00:41:00", "00:42:00", "00:43:00", "00:44:00", "00:45:00", "00:46:00", "00:47:00", "00:48:00", "00:49:00", "00:50:00", "00:51:00", "00:52:00", "00:53:00", "00:54:00", "00:55:
# ...

# %%
ddf = pd.read_csv('howpop_train.csv')

# %%
ddf.groupby(['author','post_id']).count()['votes_minus'].nlargest(20)
# Out:
# author                 post_id
# @Mithgol               284766     2
# @SLY_G                 280798     2
# @alizar                280546     2
# @0000168               159923     1
#                        160295     1
#                        161433     1
#                        166595     1
#                        171815     1
#                        175429     1
#                        176089     1
#                        176459     1
#                        177329     1
#                        178949     1
#                        181522     1
#                        308292     1
#                        313430     1
# @004helix              269835     1
# @01000110110010010010  27035      1
#                        30505      1
#                        116267     1
# Name: votes_minus, dtype: int64
